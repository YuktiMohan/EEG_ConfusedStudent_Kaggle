# %% [markdown]
# <a href="https://colab.research.google.com/github/YuktiMohan/EEG_ConfusedStudent_Kaggle/blob/master/Lesson%201%3A%20Introduction/L-1A%3A%20Hello%20world%20of%20Deep%20Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#To make sure we use the latest version of tensorflow

# %tensorflow_version 2.x

# %%
#Importing required libraries, packages and frameworks

import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
model = tf.keras.Sequential(keras.layers.Dense(units=1, input_shape = [1]))

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
x = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
y = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
model.fit(x ,y, epochs = 500)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 59
# Epoch 1/500
# 1/1 [==============================] - 0s 3ms/step - loss: 24.8051
# Epoch 2/500
# 1/1 [==============================] - 0s 1ms/step - loss: 19.8048
# Epoch 3/500
# 1/1 [==============================] - 0s 3ms/step - loss: 15.8650
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 12.7594
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 10.3105
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 8.3781
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 6.8524
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 5.6467
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 4.6928
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9372
# Epoch 11/500
# ...

# %%
print(model.predict([8]))
print(model.predict([10]))
print(model.predict([15]))
# Out:
# [[14.985686]]
# [[18.979843]]
# [[28.965237]]
